# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(5)
y = (20, 35, 30, 35, 27)
plt.bar(x, y)

plt.show()
plt.scatter(x, y)
plt.show()

# %%
import pandas as pd
df = pd.read_csv('iris.csv')
df.hist()
df.plot()
df.boxplot()
# Out:
# <AxesSubplot:>
